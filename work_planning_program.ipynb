# %% [markdown]
# # Algorithm
#
# ## 1. Load data
#
# - Data structure: list of dictionary {"work_id", "work_description", "dependency", "component", "time_cost"}
#
# ## 2. Get all the relationship ("draw" the full map - refer here: https://miro.com/app/board/uXjVLEJLvHU=/?share_link_id=541552270638)
#
# - Actually, it seems that this step is not necessary. Yesterday, I drawn the chart out using the relationships in the table in order to visualize the full nexus of work then to group and prioritize them
#
# - When drawing the chart, I went down line by line and just drew without infering any new relationship. So it was just about direct relationship; when mapping out, all of these direct relationships between the nodes create a picture of a nexus and the indirect relationship and the structure of the network is revealed.
#
# - No the above thinking is not correct. Actually, in the spreadsheet table, we know the full list of parents of each node but do not see the full list of children of each node --> so actually, drawing the map out and connecting the nodes create more information (more inference)!
#
# - Procedure:
#     + Must setup the table {"node_id", "parents", "children"} first
#     + Go through each line of the loaded table
#     + For each line, check the work_id first to update the parent list of it, then go through the parents and update the children list of it
#
#
# ## 3. Sort the work items ("coloring" - refer here: https://miro.com/app/board/uXjVLEJLvHU=/?share_link_id=541552270638)
#
# - Iteration 1:
#    + Go through all the nodes. The nodes having no dependency/component will be assigned order = 1 (the order (color) data of these nodes will be saved to a dictionary name node_order)
#
# - Iteration 2:
#    + Current order = 2
#    + Go through all the nodes that have been colored (order-assigned), check the un-ordered (un-colored) children of these nodes.
#       + If all the parent nodes of that child node have been order-assigned 1 --> update the order of the child node to 2
#       + Else, that child node will not be colored in this round (because some of the work items that it depends on have not been completed so it cannot start this round)
#
# - Iteration N (N>2):
#    + Current order = N
#    + Go through all the nodes that have been colored (order-assigned), check the un-ordered (un-colored) children of these nodes.
#        + If all the parent nodes of that child node have been order-assigned an order which is less than N (can be N-1, N-2, anything but cannot be N) --> update the order of the child node to N
#        + Else, that child node will not be colored in this round (because some of the work items that it depends on have not been completed so it cannot start this round)
#
# - In order to perform this step:
#
#     + Must know the children and parents of each node --> so still need to do step 2 --> a list of dictionary {"node_id", "parents", "children"}
#
#     + At the start of each iteration, must know the color of each node/ the current order assigned to each node. During the iteration when going through the nodes, will update this color/order database --> data structure: a list of dictionary {"node_id", "order"}
#
#     + Must write the read/write functions for these data strucure

# %%
import pandas as pd
import math
import json

# %%
# Helper functions

# %%
def string_to_list(input_string):
#     print(input_string)
    
    try:
        if input_string == '-' or input_string == '- ':
            return []
        else:
            return [item.strip() for item in input_string.split(',')]
    except:
        return []

# %%
def convert_work_item_row(row):
    return {
        'work_id': row['work_id'],
        'work_description': row['work_description'],
        'dependency': string_to_list(row['dependency']),
        'component': string_to_list(row['component']),
        'time_cost': row['time_cost']
    }

# %%
class NodeRelationships:
    
    def __init__(self):
        self.table = []
        
    def is_node_in_the_table(self, node_id):
#         only count main node, children and parents of main nodes do not count
        for row in self.table:
            if row['id'] == node_id:
                return True
        return False
    
    def initiate_new_node(self, node_id):
        self.table.append(
            {"id": node_id,
             "parents": [],
             "children": []
            }
        )
        
    def display_node_info(self, node_id):
        for row in self.table:
            if row['id'] == node_id:
                print(row)
                break
                
    def display_full_table(self):
        print(self.table)
    
    def add_parent(self, node_id, parent_id):
        for row in self.table:
            if row['id'] == node_id:
                if not(parent_id in row['parents']): 
                       row['parents'].append(parent_id)
                       break
                else:
                       break
    
    def add_child(self, node_id, child_id):
        for row in self.table:
            if row['id'] == node_id:
                if not(child_id in row['children']): 
                       row['children'].append(child_id)
                       break
                else:
                       break
    
    def add_parent_list(self, node_id, parent_id_list):
        for parent_id in parent_id_list:
            self.add_parent(node_id, parent_id)
    
    def add_children_list(self, node_id, child_id_list):
        for child_id in child_id_list:
            self.add_child(node_id, child_id)
    
    def get_parents(self, node_id):
        if not self.is_node_in_the_table(node_id):
            raise Exception("Node {} not in the table!".format(node_id))
        else:
            for row in self.table:
                if row['id'] == node_id:
                    return row['parents']
    
    def get_children(self, node_id):
        if not self.is_node_in_the_table(node_id):
            raise Exception("Node {} not in the table!".format(node_id))
        else:
            for row in self.table:
                if row['id'] == node_id:
                    return row['children']

# %%
# test

# node_relationships = NodeRelationships()
# node_relationships.initiate_new_node("ID-005-497")
# node_relationships.add_parent("ID-005-497", "ID-018-195")
# node_relationships.add_child("ID-005-497", "ID-003-270")
# node_relationships.initiate_new_node("ID-006-400")
# node_relationships.add_parent_list("ID-006-400", ['ID-013-399', 'ID-014-944', 'ID-015-251', 'ID-016-980'])
# node_relationships.add_children_list("ID-006-400", ['yolo'])
# node_relationships.get_parents('ID-006-400')

# %%
class NodeOrders:
    
    def __init__(self):
        self.table = []

    def is_node_in_the_table(self, node_id):
#         only count main node, children and parents of main nodes do not count
        for row in self.table:
            if row['id'] == node_id:
                return True
        return False
    
    def initiate_new_node(self, node_id):
#         -1 for non-assigned order
        self.table.append(
            {"id": node_id,
             "order": -1
            }
        )
    
    def get_node_order(self, node_id):
        if not self.is_node_in_the_table(node_id):
            raise Exception("node_id {} not in the table yet!".format(node_id))
        else:
            for row in self.table:
                if row['id'] == node_id:
                    return row['order']

    def display_node_info(self, node_id):
        for row in self.table:
            if row['id'] == node_id:
                print(row)
                break

    def display_full_table(self):
        print(self.table)
    
    def assign_order(self, node_id, order):
        if not self.is_node_in_the_table(node_id):
            self.initiate_new_node(node_id)
        for row in self.table:
            if row['id'] == node_id:
                row['order'] = order
                break

    def get_ordered_nodes(self):
        result = []
        for row in self.table:
            if row["order"] > 0:
                result.append(row["id"])
        return result

    
    def get_unordered_nodes(self):
        result = []
        for row in self.table:
            if row["order"] == -1:
                result.append(row["id"])
        return result
    
    def get_nodes_of_order(self, order):
        result = []
        for row in self.table:
            if row["order"] == order:
                result.append(row["id"])
        return result
    
    def get_highest_order(self):
        result = -1
        for row in self.table:
            if row['order'] > result:
                result = row['order']
        return result

# %%
# test

# node_orders = NodeOrders()
# node_orders.assign_order("ID-003-270", 1)
# node_orders.assign_order("ID-003-270", 2)
# node_orders.initiate_new_node("ID-020-196")
# node_orders.assign_order("ID-020-196", 1)
# node_orders.initiate_new_node("ID-058-779")
# node_orders.display_full_table()
# node_orders.get_unordered_nodes()
# node_orders.get_node_order("ID-003-270")
# node_orders.get_unordered_nodes()

# %%
# Step 1

# %%
df_work_item_list = pd.read_csv("input/work_item_list.csv")

# %%
df_work_item_list
# Out:
#         work_id                                   work_description  \
# 0    ID-002-528  slide 0 (cover slide - cover): craft the whole...
# 1    ID-003-270  slide 1 (table of content - table of content -...
# 2    ID-004-742  slide 2 (executive summary - section intro): c...
# 3    ID-005-497  slide 3 (executive summary - main content - 20...
# 4    ID-006-400  slide 3 (executive summary - main content - 20...
# ..          ...                                                ...
# 96   ID-098-535  slide 16 (2025 targeted genres - main content ...
# 97   ID-099-829  slide 16 (2025 targeted genres - main content ...
# 98   ID-100-476  slide 16 (2025 targeted genres - main content ...
# 99   ID-101-626  slide 16 (2025 targeted genres - main content ...
# 100  ID-102-525  slide 16 (2025 targeted genres - main content ...
#
#                                          dependency component  time_cost
# 0                                                 -         -        5.0
# 1                                                 -         -        8.0
# 2                                                 -         -        5.0
# 3                            ID-018-195, ID-019-410         -       30.0
# 4    ID-013-399, ID-014-944, ID-015-251, ID-016-980         -       30.0
# ..                                              ...       ...        ...
# 96                                       ID-097-378         -       15.0
# 97                                       ID-069-498         -        0.0
# 98                                       ID-076-997         -       30.0
# 99                                       ID-080-677         -       45.0
# 100              ID-099-829, ID-100-476, ID-101-626         -       30.0
#
# [101 rows x 5 columns]

# %%
table_work_item_info = df_work_item_list.to_dict(orient='records')

# %%
table_work_item_info
# Out:
# [{'work_id': 'ID-002-528',
#   'work_description': 'slide 0 (cover slide - cover): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-003-270',
#   'work_description': 'slide 1 (table of content - table of content - table of content): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 8.0},
#  {'work_id': 'ID-004-742',
#   'work_description': 'slide 2 (executive summary - section intro): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-005-497',
#   'work_description': "slide 3 (executive summary - main content - 2024 review): add remark on 2024's targeted genres' performance ",
#   'dependency': 'ID-018-195, ID-019-410',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-006-400',
#   'work_description': 'slide 3 (executive summary - main content - 2024 review): add remark on top-performing genres and new games of 2024',
#   'dependency': 'ID-013-399, ID-014-944, ID-015-251, ID-016-980',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-007-148',
#   'work_description': 'slide 3 (executive summary - main content - 2024 review): add charts & figures',
#   'dependency': 'ID-005-497, ID-006-400',
#   'component': '-',
#   'time_cost': 60.0},
#  {'work_id': 'ID-008-662',
#   'work_description': 'slide 3 (executive summary - main content - 2024 review): assemble the slide',
#   'dependency': 'ID-005-497, ID-006-400, ID-007-148',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-009-878',
#   'work_description': 'slide 4 (executive summary - main content - 2025 outlook): add main remark on the most promising genres to focus in 2025',
#   'dependency': 'ID-037-380',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-010-747',
#   'work_description': 'slide 4 (executive summary - main content - 2025 outlook): add other remarks on interesting findings from the data',
#   'dependency': 'ID-037-380',
#   'component': '-',
#   'time_cost': 60.0},
#  {'work_id': 'ID-011-599',
#   'work_description': 'slide 4 (executive summary - main content - 2025 outlook): assemble the slide',
#   'dependency': 'ID-009-878, ID-010-747',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-012-524',
#   'work_description': 'slide 5 (2024 review - section intro): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-013-399',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): create table top 10 genres in terms of revenue in 2024',
#   'dependency': '-',
#   'component': 'ID-047-939, ID-048-126',
#   'time_cost': 1373.0},
#  {'work_id': 'ID-014-944',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): create table top 10 genres in terms of revenue growth rate in 2024 (compared to 2023)',
#   'dependency': '-',
#   'component': 'ID-062-375, ID-063-325',
#   'time_cost': 428.0},
#  {'work_id': 'ID-015-251',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): create table top 20 games released in 2024 (in terms of 1st 60-day revenue) with their genres',
#   'dependency': '-',
#   'component': 'ID-069-498, ID-070-555, ID-071-274, ID-072-840',
#   'time_cost': 415.0},
#  {'work_id': 'ID-016-980',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): top new games in 2024 belong to genres:...',
#   'dependency': 'ID-015-251',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-017-925',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): assemble the slide',
#   'dependency': 'ID-013-399, ID-014-944, ID-015-251, ID-016-980',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-018-195',
#   'work_description': "slide 7 (2024 review - main content - targeted genres' 2024 performance): create table revenue, download, revenue growth, download growth, market share change of 3 targeted genres in 2024",
#   'dependency': 'ID-017-925',
#   'component': '-',
#   'time_cost': 20.0},
#  {'work_id': 'ID-019-410',
#   'work_description': "slide 7 (2024 review - main content - targeted genres' 2024 performance): create bar chart annual revenue (last 5 years - 2020 til 2024) of 3 targeted genres, overlaid with vn market's revenue & download chart",
#   'dependency': 'ID-017-925',
#   'component': '-',
#   'time_cost': 500.0},
#  {'work_id': 'ID-020-312',
#   'work_description': "slide 7 (2024 review - main content - targeted genres' 2024 performance): assemble the slide",
#   'dependency': 'ID-018-195, ID-019-410',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-021-108',
#   'work_description': "slide 8 (2024 review - main content - targeted genres's prominent new games): calculate top 3 new games in terms of 2024 1st 60-day revenue for 3 targeted genres (4x strategy, mmorpg+, turn-based rpg)",
#   'dependency': 'ID-015-251',
#   'component': '-',
#   'time_cost': 100.0},
#  {'work_id': 'ID-022-200',
#   'work_description': "slide 8 (2024 review - main content - targeted genres's prominent new games): find & write down game info (revenue, publishing date, publisher) for 3 x 3 = 9 games",
#   'dependency': 'ID-021-108',
#   'component': '-',
#   'time_cost': 90.0},
#  {'work_id': 'ID-023-455',
#   'work_description': "slide 8 (2024 review - main content - targeted genres's prominent new games): assemble the slide",
#   'dependency': 'ID-021-108, ID-022-200',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-024-388',
#   'work_description': 'slide 9 (2024 review - main content - 2024 forecast review): craft the whole slide',
#   'dependency': 'ID-017-925, ID-020-312, ID-023-455',
#   'component': '-',
#   'time_cost': 20.0},
#  {'work_id': 'ID-025-803',
#   'work_description': 'slide 10 (2025 methodology - section intro): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-026-947',
#   'work_description': 'slide 11 (2025 methodology - main content - method description): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 90.0},
#  {'work_id': 'ID-027-918',
#   'work_description': 'slide 12 (2025 methodology - main content - compare & contrast the 2 methods): craft the whole slide',
#   'dependency': 'ID-026-947',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-028-310',
#   'work_description': 'slide 13 (2025 targeted genres - section intro): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-029-120',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn): calculate the top genres in terms of market share (2023 & 2024) and/or cagr (2014 - 2023)',
#   'dependency': '-',
#   'component': 'ID-083-154, ID-084-311, ID-085-702',
#   'time_cost': 1082.0},
#  {'work_id': 'ID-030-975',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn): assemble the slide',
#   'dependency': 'ID-029-120',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-031-676',
#   'work_description': "slide 15 (2025 targeted genres - main content - method 1: strong genres with market-entry opportunities for garena): analyze each of the 10 top genres from slide 14's output to highlight the genres presenting market-entry opportunities for garena",
#   'dependency': 'ID-030-975',
#   'component': '-',
#   'time_cost': 1600.0},
#  {'work_id': 'ID-032-983',
#   'work_description': 'slide 15 (2025 targeted genres - main content - method 1: strong genres with market-entry opportunities for garena): assemble the slide',
#   'dependency': 'ID-031-676',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-033-245',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games): calculate top 10 new games having highest 1st year revenue in 2023 - 2024 and their genres',
#   'dependency': '-',
#   'component': 'ID-096-214, ID-097-378, ID-098-535',
#   'time_cost': 130.0},
#  {'work_id': 'ID-034-332',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games): assemble the slide',
#   'dependency': 'ID-033-245',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-035-201',
#   'work_description': 'slide 17 (2025 targeted genres - main content - method 2: outstanding games): analyze each of the top 10 new games from the output of slide 16 to come up with insights',
#   'dependency': 'ID-033-245',
#   'component': '-',
#   'time_cost': 1200.0},
#  {'work_id': 'ID-036-676',
#   'work_description': 'slide 17 (2025 targeted genres - main content - method 2: outstanding games): assemble the slide',
#   'dependency': 'ID-035-201',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-037-380',
#   'work_description': 'slide 18 (2025 targeted genres - main content - targeted genres for sourcing in 2025): craft the whole slide',
#   'dependency': 'ID-032-983, ID-036-676',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-038-716',
#   'work_description': 'slide 19 (other recommendations - section intro): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-039-217',
#   'work_description': 'slide 20 (other recommendations - main content - recommendation 1:): craft the whole slide',
#   'dependency': 'ID-017-925, ID-020-312, ID-023-455, ID-030-975, ID-032-983, ID-034-332, ID-036-676',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-040-243',
#   'work_description': 'slide 21 (other recommendations - main content - recommendation 2:): craft the whole slide',
#   'dependency': 'ID-017-925, ID-020-312, ID-023-455, ID-030-975, ID-032-983, ID-034-332, ID-036-676',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-041-402',
#   'work_description': 'slide 22 (report automation - section intro): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-042-189',
#   'work_description': 'slide 23 (report automation - main content - report components): craft the whole slide',
#   'dependency': 'ID-017-925, ID-020-312, ID-023-455, ID-030-975, ID-032-983, ID-034-332, ID-036-676',
#   'component': '-',
#   'time_cost': 180.0},
#  {'work_id': 'ID-043-150',
#   'work_description': 'slide 24 (report automation - main content - automation planning): craft the whole slide',
#   'dependency': 'ID-042-189',
#   'component': '-',
#   'time_cost': 180.0},
#  {'work_id': 'ID-044-498',
#   'work_description': 'slide 25 (appendix - section intro): craft the whole slide',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-045-335',
#   'work_description': 'slide 26 (appendix - main content - appendix 1): craft the whole slide',
#   'dependency': 'ID-043-150',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-046-240',
#   'work_description': 'slide 27 (appendix - main content - appendix 2): craft the whole slide',
#   'dependency': 'ID-043-150',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-047-939',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the numbers top 10 genres in terms of revenue for 2024',
#   'dependency': '-',
#   'component': 'ID-049-855, ID-050-720, ID-051-563',
#   'time_cost': nan},
#  {'work_id': 'ID-048-126',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): draw the table from the calculated numbers',
#   'dependency': 'ID-047-939',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-049-855',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): calculate revenue of all genres for 2024 (outcome: table of "genre - revenue")',
#   'dependency': '-',
#   'component': 'ID-052-345, ID-053-731',
#   'time_cost': nan},
#  {'work_id': 'ID-050-720',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): sort the "genre-revenue-download" table in descending order from highest revenue to lowest revenue',
#   'dependency': 'ID-049-855',
#   'component': '-',
#   'time_cost': 1.0},
#  {'work_id': 'ID-051-563',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the top 10 grossing genres',
#   'dependency': 'ID-050-720',
#   'component': '-',
#   'time_cost': 2.0},
#  {'work_id': 'ID-052-345',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the data of "game - genre - revenue - download" of 2024 (revenue from 24/01/01 to ideally 24/11/30 or an earlier date in November) from SensorTower',
#   'dependency': '-',
#   'component': 'ID-054-887, ID-055-848, ID-056-519, ID-057-425',
#   'time_cost': 20.0},
#  {'work_id': 'ID-053-731',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): calculate the revenue & download of all genres for 2024 (outcome: table of "genre - revenue - download")',
#   'dependency': 'ID-052-345',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-054-887',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): manually download "game-download-revenue" (ytd, 2024) data from sensortower',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-055-848',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the metadata "game-class-genre-subgenre" using api from sensortower',
#   'dependency': 'ID-054-887',
#   'component': 'ID-058-363, ID-059-251, ID-060-849, ID-061-296',
#   'time_cost': nan},
#  {'work_id': 'ID-056-519',
#   'work_description': "slide 6 (2024 review - main content - 2024 top genres & new games - p1): clean sensortower's genre metadata (2024)",
#   'dependency': 'ID-055-848',
#   'component': '-',
#   'time_cost': 1200.0},
#  {'work_id': 'ID-057-425',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): join previous outputs to get the desired output of "game - genre - revenue - download" of 2024',
#   'dependency': 'ID-054-887, ID-056-519',
#   'component': '-',
#   'time_cost': nan},
#  {'work_id': 'ID-058-363',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): extract the list of "unified_app_id" from the "game-download-revenue" data downloaded manually from sensortower ',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-059-251',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the mapping of "unified_app_id - canonical_app_id" from these unified_app_ids using the python function "get_unified_app_data"',
#   'dependency': 'ID-058-363',
#   'component': '-',
#   'time_cost': 40.0},
#  {'work_id': 'ID-060-849',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): use the previous list as input to the python function "get_required_tags" to get the data "canonical_app_id - game_class - game_genre - game_subgenre"',
#   'dependency': 'ID-059-251',
#   'component': '-',
#   'time_cost': 40.0},
#  {'work_id': 'ID-061-296',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): join the output of previous steps to get the sensortower "game - class - genre - subgenre" metadata',
#   'dependency': 'ID-059-251, ID-060-849',
#   'component': '-',
#   'time_cost': 20.0},
#  {'work_id': 'ID-062-375',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): get the numbers top 10 genres in terms of revenue growth rate in 2024 (compared to 2023)',
#   'dependency': '-',
#   'component': 'ID-064-653, ID-065-906, ID-066-826, ID-067-967, ID-068-774',
#   'time_cost': nan},
#  {'work_id': 'ID-063-325',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): draw the table from the calculated numbers',
#   'dependency': 'ID-062-375',
#   'component': nan,
#   'time_cost': 10.0},
#  {'work_id': 'ID-064-653',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): calculate revenue of all genres for 2023 (outcome: table of "genre - revenue")',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 405.0},
#  {'work_id': 'ID-065-906',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): prerequisite revenue of all genres for 2024 (data format: "genre - revenue")',
#   'dependency': 'ID-049-855',
#   'component': '-',
#   'time_cost': 0.0},
#  {'work_id': 'ID-066-826',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): calculate revenue growth of each genre between 2023 - 2024 (outcome: table of "genre - revenue growth")',
#   'dependency': 'ID-064-653, ID-065-906',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-067-967',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): sort the output of previous step from highest to lowest growth rate',
#   'dependency': 'ID-066-826',
#   'component': '-',
#   'time_cost': 2.0},
#  {'work_id': 'ID-068-774',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): get the top 10 high-growth genres',
#   'dependency': 'ID-067-967',
#   'component': '-',
#   'time_cost': 1.0},
#  {'work_id': 'ID-069-498',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): get the list of all games released in 2024',
#   'dependency': '-',
#   'component': 'ID-073-450, ID-074-451, ID-075-266, ID-076-997, ID-077-281, ID-078-914',
#   'time_cost': nan},
#  {'work_id': 'ID-070-555',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): calculate the 1st 60-day revenue of these games',
#   'dependency': 'ID-069-498',
#   'component': 'ID-079-466, ID-080-677, ID-081-480, ID-082-718',
#   'time_cost': nan},
#  {'work_id': 'ID-071-274',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): get the top 20 games with highest 1st 60-day revenue from the output of previous step',
#   'dependency': 'ID-070-555',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-072-840',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): draw the table from the calculated numbers',
#   'dependency': 'ID-071-274',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-073-450',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): prerequisite: the list of "unified_app_id" (output of p1 - 1.1.1.2.1 but in the form of python dictionary (no need to export to csv))',
#   'dependency': 'ID-058-363',
#   'component': '-',
#   'time_cost': 0.0},
#  {'work_id': 'ID-074-451',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): get all the local_app_info of previous step\'s output\'s unified_app_id using python script (section: "get app overview data (local app info)"; each of these app_ids has a different release_date)',
#   'dependency': 'ID-073-450',
#   'component': '-',
#   'time_cost': 20.0},
#  {'work_id': 'ID-075-266',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (3) finalize logic on how to get the right release_date from multiple local app_ids of a single unified_app_id',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-076-997',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (4) turn (3) into python script',
#   'dependency': 'ID-075-266',
#   'component': '-',
#   'time_cost': 60.0},
#  {'work_id': 'ID-077-281',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (5) run the script on (2)\'s output to get "unified_app_id - release_date"',
#   'dependency': 'ID-074-451',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-078-914',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (6) filter out the games whose released dates are in 2024 (output: python list)',
#   'dependency': 'ID-077-281',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-079-466',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (1) come up with query logic to get the 1st 60-day revenue of 2024 new games',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 180.0},
#  {'work_id': 'ID-080-677',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (2) turn the logic into python script',
#   'dependency': 'ID-079-466',
#   'component': '-',
#   'time_cost': 60.0},
#  {'work_id': 'ID-081-480',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (3) run the script to get the 1st 60-day revenues of the games',
#   'dependency': 'ID-080-677',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-082-718',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (4) import the data "unified_app_id - 1st-60day-revenue" of 2024 new games to gg sheet',
#   'dependency': 'ID-081-480',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-083-154',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) get the genres having highest market share in 2023 & 2024',
#   'dependency': '-',
#   'component': 'ID-086-474, ID-087-286',
#   'time_cost': nan},
#  {'work_id': 'ID-084-311',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) get the genres having highest cagr (2014 - 2023)',
#   'dependency': '-',
#   'component': 'ID-088-916, ID-089-723',
#   'time_cost': nan},
#  {'work_id': 'ID-085-702',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (3) get the 10 genres that are on top of both market share & cagr',
#   'dependency': 'ID-083-154, ID-084-311',
#   'component': '- ',
#   'time_cost': 20.0},
#  {'work_id': 'ID-086-474',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) get the data "genre - market share" for 2023 & 2024 (revenue combined for 2 years)',
#   'dependency': '-',
#   'component': 'ID-090-485, ID-091-105',
#   'time_cost': nan},
#  {'work_id': 'ID-087-286',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) sort the output of (1) in descending order in terms of market share',
#   'dependency': 'ID-086-474',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-088-916',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) get the data "year - genre - cagr 2014 - 2023"',
#   'dependency': '-',
#   'component': 'ID-093-937, ID-094-369, ID-095-734',
#   'time_cost': nan},
#  {'work_id': 'ID-089-723',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) sort the output of (1) in descending order in terms of cagr',
#   'dependency': 'ID-088-916',
#   'component': '-',
#   'time_cost': 5.0},
#  {'work_id': 'ID-090-485',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) calculate "genre - revenue" for all genres in 2023 & 2024',
#   'dependency': 'ID-049-855, ID-064-653',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-091-105',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) calculate total revenue of 2023 and 2024',
#   'dependency': 'ID-054-887, ID-064-653',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-092-720',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (3) calculate "year-genre-market share" for all genres in 2023 & 2024',
#   'dependency': 'ID-090-485, ID-091-105',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-093-937',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) download the full-year revenue data for 2014 - 2024 from sensortower',
#   'dependency': '-',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-094-369',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) check and clean the genre data of 2014 til 2019 (2020 til 2024 already cleaned in previous work)',
#   'dependency': 'ID-093-937',
#   'component': '-',
#   'time_cost': 992.0},
#  {'work_id': 'ID-095-734',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (3) calculate cagr for every genre 2014 - 2024',
#   'dependency': 'ID-093-937, ID-094-369',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-096-214',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (1) calculate the 1st year revenue of games released in 2023 and 2024',
#   'dependency': '-',
#   'component': 'ID-099-829, ID-100-476, ID-101-626, ID-102-525',
#   'time_cost': nan},
#  {'work_id': 'ID-097-378',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (2) sort the output of (1) in descending order in terms of 1st-year revenue',
#   'dependency': 'ID-096-214',
#   'component': '-',
#   'time_cost': 10.0},
#  {'work_id': 'ID-098-535',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (3) get the top 10 and put it into a table together with genres',
#   'dependency': 'ID-097-378',
#   'component': '-',
#   'time_cost': 15.0},
#  {'work_id': 'ID-099-829',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (1) use the list of all games released during 2024',
#   'dependency': 'ID-069-498',
#   'component': '-',
#   'time_cost': 0.0},
#  {'work_id': 'ID-100-476',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (2) get the list of games released during 2023',
#   'dependency': 'ID-076-997',
#   'component': '-',
#   'time_cost': 30.0},
#  {'work_id': 'ID-101-626',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (3) write a new script for calculation of 1st-year revenue',
#   'dependency': 'ID-080-677',
#   'component': '-',
#   'time_cost': 45.0},
#  {'work_id': 'ID-102-525',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (4) run the script to calculate 1st-year revenue of all newly released games in 2023 and 2024',
#   'dependency': 'ID-099-829, ID-100-476, ID-101-626',
#   'component': '-',
#   'time_cost': 30.0}]

# %%
table_work_item_info = list(map(lambda x: convert_work_item_row(x), table_work_item_info))

# %%
table_work_item_info
# Out:
# [{'work_id': 'ID-002-528',
#   'work_description': 'slide 0 (cover slide - cover): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-003-270',
#   'work_description': 'slide 1 (table of content - table of content - table of content): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 8.0},
#  {'work_id': 'ID-004-742',
#   'work_description': 'slide 2 (executive summary - section intro): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-005-497',
#   'work_description': "slide 3 (executive summary - main content - 2024 review): add remark on 2024's targeted genres' performance ",
#   'dependency': ['ID-018-195', 'ID-019-410'],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-006-400',
#   'work_description': 'slide 3 (executive summary - main content - 2024 review): add remark on top-performing genres and new games of 2024',
#   'dependency': ['ID-013-399', 'ID-014-944', 'ID-015-251', 'ID-016-980'],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-007-148',
#   'work_description': 'slide 3 (executive summary - main content - 2024 review): add charts & figures',
#   'dependency': ['ID-005-497', 'ID-006-400'],
#   'component': [],
#   'time_cost': 60.0},
#  {'work_id': 'ID-008-662',
#   'work_description': 'slide 3 (executive summary - main content - 2024 review): assemble the slide',
#   'dependency': ['ID-005-497', 'ID-006-400', 'ID-007-148'],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-009-878',
#   'work_description': 'slide 4 (executive summary - main content - 2025 outlook): add main remark on the most promising genres to focus in 2025',
#   'dependency': ['ID-037-380'],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-010-747',
#   'work_description': 'slide 4 (executive summary - main content - 2025 outlook): add other remarks on interesting findings from the data',
#   'dependency': ['ID-037-380'],
#   'component': [],
#   'time_cost': 60.0},
#  {'work_id': 'ID-011-599',
#   'work_description': 'slide 4 (executive summary - main content - 2025 outlook): assemble the slide',
#   'dependency': ['ID-009-878', 'ID-010-747'],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-012-524',
#   'work_description': 'slide 5 (2024 review - section intro): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-013-399',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): create table top 10 genres in terms of revenue in 2024',
#   'dependency': [],
#   'component': ['ID-047-939', 'ID-048-126'],
#   'time_cost': 1373.0},
#  {'work_id': 'ID-014-944',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): create table top 10 genres in terms of revenue growth rate in 2024 (compared to 2023)',
#   'dependency': [],
#   'component': ['ID-062-375', 'ID-063-325'],
#   'time_cost': 428.0},
#  {'work_id': 'ID-015-251',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): create table top 20 games released in 2024 (in terms of 1st 60-day revenue) with their genres',
#   'dependency': [],
#   'component': ['ID-069-498', 'ID-070-555', 'ID-071-274', 'ID-072-840'],
#   'time_cost': 415.0},
#  {'work_id': 'ID-016-980',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): top new games in 2024 belong to genres:...',
#   'dependency': ['ID-015-251'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-017-925',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games): assemble the slide',
#   'dependency': ['ID-013-399', 'ID-014-944', 'ID-015-251', 'ID-016-980'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-018-195',
#   'work_description': "slide 7 (2024 review - main content - targeted genres' 2024 performance): create table revenue, download, revenue growth, download growth, market share change of 3 targeted genres in 2024",
#   'dependency': ['ID-017-925'],
#   'component': [],
#   'time_cost': 20.0},
#  {'work_id': 'ID-019-410',
#   'work_description': "slide 7 (2024 review - main content - targeted genres' 2024 performance): create bar chart annual revenue (last 5 years - 2020 til 2024) of 3 targeted genres, overlaid with vn market's revenue & download chart",
#   'dependency': ['ID-017-925'],
#   'component': [],
#   'time_cost': 500.0},
#  {'work_id': 'ID-020-312',
#   'work_description': "slide 7 (2024 review - main content - targeted genres' 2024 performance): assemble the slide",
#   'dependency': ['ID-018-195', 'ID-019-410'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-021-108',
#   'work_description': "slide 8 (2024 review - main content - targeted genres's prominent new games): calculate top 3 new games in terms of 2024 1st 60-day revenue for 3 targeted genres (4x strategy, mmorpg+, turn-based rpg)",
#   'dependency': ['ID-015-251'],
#   'component': [],
#   'time_cost': 100.0},
#  {'work_id': 'ID-022-200',
#   'work_description': "slide 8 (2024 review - main content - targeted genres's prominent new games): find & write down game info (revenue, publishing date, publisher) for 3 x 3 = 9 games",
#   'dependency': ['ID-021-108'],
#   'component': [],
#   'time_cost': 90.0},
#  {'work_id': 'ID-023-455',
#   'work_description': "slide 8 (2024 review - main content - targeted genres's prominent new games): assemble the slide",
#   'dependency': ['ID-021-108', 'ID-022-200'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-024-388',
#   'work_description': 'slide 9 (2024 review - main content - 2024 forecast review): craft the whole slide',
#   'dependency': ['ID-017-925', 'ID-020-312', 'ID-023-455'],
#   'component': [],
#   'time_cost': 20.0},
#  {'work_id': 'ID-025-803',
#   'work_description': 'slide 10 (2025 methodology - section intro): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-026-947',
#   'work_description': 'slide 11 (2025 methodology - main content - method description): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 90.0},
#  {'work_id': 'ID-027-918',
#   'work_description': 'slide 12 (2025 methodology - main content - compare & contrast the 2 methods): craft the whole slide',
#   'dependency': ['ID-026-947'],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-028-310',
#   'work_description': 'slide 13 (2025 targeted genres - section intro): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-029-120',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn): calculate the top genres in terms of market share (2023 & 2024) and/or cagr (2014 - 2023)',
#   'dependency': [],
#   'component': ['ID-083-154', 'ID-084-311', 'ID-085-702'],
#   'time_cost': 1082.0},
#  {'work_id': 'ID-030-975',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn): assemble the slide',
#   'dependency': ['ID-029-120'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-031-676',
#   'work_description': "slide 15 (2025 targeted genres - main content - method 1: strong genres with market-entry opportunities for garena): analyze each of the 10 top genres from slide 14's output to highlight the genres presenting market-entry opportunities for garena",
#   'dependency': ['ID-030-975'],
#   'component': [],
#   'time_cost': 1600.0},
#  {'work_id': 'ID-032-983',
#   'work_description': 'slide 15 (2025 targeted genres - main content - method 1: strong genres with market-entry opportunities for garena): assemble the slide',
#   'dependency': ['ID-031-676'],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-033-245',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games): calculate top 10 new games having highest 1st year revenue in 2023 - 2024 and their genres',
#   'dependency': [],
#   'component': ['ID-096-214', 'ID-097-378', 'ID-098-535'],
#   'time_cost': 130.0},
#  {'work_id': 'ID-034-332',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games): assemble the slide',
#   'dependency': ['ID-033-245'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-035-201',
#   'work_description': 'slide 17 (2025 targeted genres - main content - method 2: outstanding games): analyze each of the top 10 new games from the output of slide 16 to come up with insights',
#   'dependency': ['ID-033-245'],
#   'component': [],
#   'time_cost': 1200.0},
#  {'work_id': 'ID-036-676',
#   'work_description': 'slide 17 (2025 targeted genres - main content - method 2: outstanding games): assemble the slide',
#   'dependency': ['ID-035-201'],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-037-380',
#   'work_description': 'slide 18 (2025 targeted genres - main content - targeted genres for sourcing in 2025): craft the whole slide',
#   'dependency': ['ID-032-983', 'ID-036-676'],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-038-716',
#   'work_description': 'slide 19 (other recommendations - section intro): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-039-217',
#   'work_description': 'slide 20 (other recommendations - main content - recommendation 1:): craft the whole slide',
#   'dependency': ['ID-017-925',
#    'ID-020-312',
#    'ID-023-455',
#    'ID-030-975',
#    'ID-032-983',
#    'ID-034-332',
#    'ID-036-676'],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-040-243',
#   'work_description': 'slide 21 (other recommendations - main content - recommendation 2:): craft the whole slide',
#   'dependency': ['ID-017-925',
#    'ID-020-312',
#    'ID-023-455',
#    'ID-030-975',
#    'ID-032-983',
#    'ID-034-332',
#    'ID-036-676'],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-041-402',
#   'work_description': 'slide 22 (report automation - section intro): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-042-189',
#   'work_description': 'slide 23 (report automation - main content - report components): craft the whole slide',
#   'dependency': ['ID-017-925',
#    'ID-020-312',
#    'ID-023-455',
#    'ID-030-975',
#    'ID-032-983',
#    'ID-034-332',
#    'ID-036-676'],
#   'component': [],
#   'time_cost': 180.0},
#  {'work_id': 'ID-043-150',
#   'work_description': 'slide 24 (report automation - main content - automation planning): craft the whole slide',
#   'dependency': ['ID-042-189'],
#   'component': [],
#   'time_cost': 180.0},
#  {'work_id': 'ID-044-498',
#   'work_description': 'slide 25 (appendix - section intro): craft the whole slide',
#   'dependency': [],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-045-335',
#   'work_description': 'slide 26 (appendix - main content - appendix 1): craft the whole slide',
#   'dependency': ['ID-043-150'],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-046-240',
#   'work_description': 'slide 27 (appendix - main content - appendix 2): craft the whole slide',
#   'dependency': ['ID-043-150'],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-047-939',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the numbers top 10 genres in terms of revenue for 2024',
#   'dependency': [],
#   'component': ['ID-049-855', 'ID-050-720', 'ID-051-563'],
#   'time_cost': nan},
#  {'work_id': 'ID-048-126',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): draw the table from the calculated numbers',
#   'dependency': ['ID-047-939'],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-049-855',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): calculate revenue of all genres for 2024 (outcome: table of "genre - revenue")',
#   'dependency': [],
#   'component': ['ID-052-345', 'ID-053-731'],
#   'time_cost': nan},
#  {'work_id': 'ID-050-720',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): sort the "genre-revenue-download" table in descending order from highest revenue to lowest revenue',
#   'dependency': ['ID-049-855'],
#   'component': [],
#   'time_cost': 1.0},
#  {'work_id': 'ID-051-563',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the top 10 grossing genres',
#   'dependency': ['ID-050-720'],
#   'component': [],
#   'time_cost': 2.0},
#  {'work_id': 'ID-052-345',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the data of "game - genre - revenue - download" of 2024 (revenue from 24/01/01 to ideally 24/11/30 or an earlier date in November) from SensorTower',
#   'dependency': [],
#   'component': ['ID-054-887', 'ID-055-848', 'ID-056-519', 'ID-057-425'],
#   'time_cost': 20.0},
#  {'work_id': 'ID-053-731',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): calculate the revenue & download of all genres for 2024 (outcome: table of "genre - revenue - download")',
#   'dependency': ['ID-052-345'],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-054-887',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): manually download "game-download-revenue" (ytd, 2024) data from sensortower',
#   'dependency': [],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-055-848',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the metadata "game-class-genre-subgenre" using api from sensortower',
#   'dependency': ['ID-054-887'],
#   'component': ['ID-058-363', 'ID-059-251', 'ID-060-849', 'ID-061-296'],
#   'time_cost': nan},
#  {'work_id': 'ID-056-519',
#   'work_description': "slide 6 (2024 review - main content - 2024 top genres & new games - p1): clean sensortower's genre metadata (2024)",
#   'dependency': ['ID-055-848'],
#   'component': [],
#   'time_cost': 1200.0},
#  {'work_id': 'ID-057-425',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): join previous outputs to get the desired output of "game - genre - revenue - download" of 2024',
#   'dependency': ['ID-054-887', 'ID-056-519'],
#   'component': [],
#   'time_cost': nan},
#  {'work_id': 'ID-058-363',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): extract the list of "unified_app_id" from the "game-download-revenue" data downloaded manually from sensortower ',
#   'dependency': [],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-059-251',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): get the mapping of "unified_app_id - canonical_app_id" from these unified_app_ids using the python function "get_unified_app_data"',
#   'dependency': ['ID-058-363'],
#   'component': [],
#   'time_cost': 40.0},
#  {'work_id': 'ID-060-849',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): use the previous list as input to the python function "get_required_tags" to get the data "canonical_app_id - game_class - game_genre - game_subgenre"',
#   'dependency': ['ID-059-251'],
#   'component': [],
#   'time_cost': 40.0},
#  {'work_id': 'ID-061-296',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p1): join the output of previous steps to get the sensortower "game - class - genre - subgenre" metadata',
#   'dependency': ['ID-059-251', 'ID-060-849'],
#   'component': [],
#   'time_cost': 20.0},
#  {'work_id': 'ID-062-375',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): get the numbers top 10 genres in terms of revenue growth rate in 2024 (compared to 2023)',
#   'dependency': [],
#   'component': ['ID-064-653',
#    'ID-065-906',
#    'ID-066-826',
#    'ID-067-967',
#    'ID-068-774'],
#   'time_cost': nan},
#  {'work_id': 'ID-063-325',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): draw the table from the calculated numbers',
#   'dependency': ['ID-062-375'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-064-653',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): calculate revenue of all genres for 2023 (outcome: table of "genre - revenue")',
#   'dependency': [],
#   'component': [],
#   'time_cost': 405.0},
#  {'work_id': 'ID-065-906',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): prerequisite revenue of all genres for 2024 (data format: "genre - revenue")',
#   'dependency': ['ID-049-855'],
#   'component': [],
#   'time_cost': 0.0},
#  {'work_id': 'ID-066-826',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): calculate revenue growth of each genre between 2023 - 2024 (outcome: table of "genre - revenue growth")',
#   'dependency': ['ID-064-653', 'ID-065-906'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-067-967',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): sort the output of previous step from highest to lowest growth rate',
#   'dependency': ['ID-066-826'],
#   'component': [],
#   'time_cost': 2.0},
#  {'work_id': 'ID-068-774',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p2): get the top 10 high-growth genres',
#   'dependency': ['ID-067-967'],
#   'component': [],
#   'time_cost': 1.0},
#  {'work_id': 'ID-069-498',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): get the list of all games released in 2024',
#   'dependency': [],
#   'component': ['ID-073-450',
#    'ID-074-451',
#    'ID-075-266',
#    'ID-076-997',
#    'ID-077-281',
#    'ID-078-914'],
#   'time_cost': nan},
#  {'work_id': 'ID-070-555',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): calculate the 1st 60-day revenue of these games',
#   'dependency': ['ID-069-498'],
#   'component': ['ID-079-466', 'ID-080-677', 'ID-081-480', 'ID-082-718'],
#   'time_cost': nan},
#  {'work_id': 'ID-071-274',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): get the top 20 games with highest 1st 60-day revenue from the output of previous step',
#   'dependency': ['ID-070-555'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-072-840',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): draw the table from the calculated numbers',
#   'dependency': ['ID-071-274'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-073-450',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): prerequisite: the list of "unified_app_id" (output of p1 - 1.1.1.2.1 but in the form of python dictionary (no need to export to csv))',
#   'dependency': ['ID-058-363'],
#   'component': [],
#   'time_cost': 0.0},
#  {'work_id': 'ID-074-451',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): get all the local_app_info of previous step\'s output\'s unified_app_id using python script (section: "get app overview data (local app info)"; each of these app_ids has a different release_date)',
#   'dependency': ['ID-073-450'],
#   'component': [],
#   'time_cost': 20.0},
#  {'work_id': 'ID-075-266',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (3) finalize logic on how to get the right release_date from multiple local app_ids of a single unified_app_id',
#   'dependency': [],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-076-997',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (4) turn (3) into python script',
#   'dependency': ['ID-075-266'],
#   'component': [],
#   'time_cost': 60.0},
#  {'work_id': 'ID-077-281',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (5) run the script on (2)\'s output to get "unified_app_id - release_date"',
#   'dependency': ['ID-074-451'],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-078-914',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (6) filter out the games whose released dates are in 2024 (output: python list)',
#   'dependency': ['ID-077-281'],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-079-466',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (1) come up with query logic to get the 1st 60-day revenue of 2024 new games',
#   'dependency': [],
#   'component': [],
#   'time_cost': 180.0},
#  {'work_id': 'ID-080-677',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (2) turn the logic into python script',
#   'dependency': ['ID-079-466'],
#   'component': [],
#   'time_cost': 60.0},
#  {'work_id': 'ID-081-480',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (3) run the script to get the 1st 60-day revenues of the games',
#   'dependency': ['ID-080-677'],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-082-718',
#   'work_description': 'slide 6 (2024 review - main content - 2024 top genres & new games - p3): (4) import the data "unified_app_id - 1st-60day-revenue" of 2024 new games to gg sheet',
#   'dependency': ['ID-081-480'],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-083-154',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) get the genres having highest market share in 2023 & 2024',
#   'dependency': [],
#   'component': ['ID-086-474', 'ID-087-286'],
#   'time_cost': nan},
#  {'work_id': 'ID-084-311',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) get the genres having highest cagr (2014 - 2023)',
#   'dependency': [],
#   'component': ['ID-088-916', 'ID-089-723'],
#   'time_cost': nan},
#  {'work_id': 'ID-085-702',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (3) get the 10 genres that are on top of both market share & cagr',
#   'dependency': ['ID-083-154', 'ID-084-311'],
#   'component': [],
#   'time_cost': 20.0},
#  {'work_id': 'ID-086-474',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) get the data "genre - market share" for 2023 & 2024 (revenue combined for 2 years)',
#   'dependency': [],
#   'component': ['ID-090-485', 'ID-091-105'],
#   'time_cost': nan},
#  {'work_id': 'ID-087-286',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) sort the output of (1) in descending order in terms of market share',
#   'dependency': ['ID-086-474'],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-088-916',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) get the data "year - genre - cagr 2014 - 2023"',
#   'dependency': [],
#   'component': ['ID-093-937', 'ID-094-369', 'ID-095-734'],
#   'time_cost': nan},
#  {'work_id': 'ID-089-723',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) sort the output of (1) in descending order in terms of cagr',
#   'dependency': ['ID-088-916'],
#   'component': [],
#   'time_cost': 5.0},
#  {'work_id': 'ID-090-485',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) calculate "genre - revenue" for all genres in 2023 & 2024',
#   'dependency': ['ID-049-855', 'ID-064-653'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-091-105',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) calculate total revenue of 2023 and 2024',
#   'dependency': ['ID-054-887', 'ID-064-653'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-092-720',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (3) calculate "year-genre-market share" for all genres in 2023 & 2024',
#   'dependency': ['ID-090-485', 'ID-091-105'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-093-937',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (1) download the full-year revenue data for 2014 - 2024 from sensortower',
#   'dependency': [],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-094-369',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (2) check and clean the genre data of 2014 til 2019 (2020 til 2024 already cleaned in previous work)',
#   'dependency': ['ID-093-937'],
#   'component': [],
#   'time_cost': 992.0},
#  {'work_id': 'ID-095-734',
#   'work_description': 'slide 14 (2025 targeted genres - main content - method 1: strongest genres in vn - p4): (3) calculate cagr for every genre 2014 - 2024',
#   'dependency': ['ID-093-937', 'ID-094-369'],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-096-214',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (1) calculate the 1st year revenue of games released in 2023 and 2024',
#   'dependency': [],
#   'component': ['ID-099-829', 'ID-100-476', 'ID-101-626', 'ID-102-525'],
#   'time_cost': nan},
#  {'work_id': 'ID-097-378',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (2) sort the output of (1) in descending order in terms of 1st-year revenue',
#   'dependency': ['ID-096-214'],
#   'component': [],
#   'time_cost': 10.0},
#  {'work_id': 'ID-098-535',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (3) get the top 10 and put it into a table together with genres',
#   'dependency': ['ID-097-378'],
#   'component': [],
#   'time_cost': 15.0},
#  {'work_id': 'ID-099-829',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (1) use the list of all games released during 2024',
#   'dependency': ['ID-069-498'],
#   'component': [],
#   'time_cost': 0.0},
#  {'work_id': 'ID-100-476',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (2) get the list of games released during 2023',
#   'dependency': ['ID-076-997'],
#   'component': [],
#   'time_cost': 30.0},
#  {'work_id': 'ID-101-626',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (3) write a new script for calculation of 1st-year revenue',
#   'dependency': ['ID-080-677'],
#   'component': [],
#   'time_cost': 45.0},
#  {'work_id': 'ID-102-525',
#   'work_description': 'slide 16 (2025 targeted genres - main content - method 2: recent successful new games - p5): (4) run the script to calculate 1st-year revenue of all newly released games in 2023 and 2024',
#   'dependency': ['ID-099-829', 'ID-100-476', 'ID-101-626'],
#   'component': [],
#   'time_cost': 30.0}]

# %%
# Step 2

# %%
node_relationships = NodeRelationships()

# %%
for row in table_work_item_info:
    
    main_node = row['work_id']
    
    main_node_parents = row['dependency'] + row['component'] 
    
    # process main node
    
    if not node_relationships.is_node_in_the_table(main_node):
        node_relationships.initiate_new_node(main_node)
        print("main node: {}".format(main_node))
    
    # add parents to main node
    node_relationships.add_parent_list(main_node, main_node_parents)
    
    # process main node's parents (add main node as child to them)
    for node in main_node_parents:
        if not node_relationships.is_node_in_the_table(node):
            node_relationships.initiate_new_node(node)
            print("parent node: {}".format(node))
        node_relationships.add_child(node, main_node)
# Out:
# main node: ID-002-528
# main node: ID-003-270
# main node: ID-004-742
# main node: ID-005-497
# parent node: ID-018-195
# parent node: ID-019-410
# main node: ID-006-400
# parent node: ID-013-399
# parent node: ID-014-944
# parent node: ID-015-251
# parent node: ID-016-980
# main node: ID-007-148
# main node: ID-008-662
# main node: ID-009-878
# parent node: ID-037-380
# main node: ID-010-747
# main node: ID-011-599
# main node: ID-012-524
# parent node: ID-047-939
# parent node: ID-048-126
# parent node: ID-062-375
# parent node: ID-063-325
# parent node: ID-069-498
# parent node: ID-070-555
# parent node: ID-071-274
# parent node: ID-072-840
# main node: ID-017-925
# main node: ID-020-312
# main node: ID-021-108
# main node: ID-022-200
# main node: ID-023-455
# main node: ID-024-388
# main node: ID-025-803
# main node: ID-026-947
# main node: ID-027-918
# main node: ID-028-310
# main node: ID-029-120
# parent node: ID-083-154
# parent node: ID-084-311
# parent node: ID-085-702
# main node: ID-030-975
# main node: ID-031-676
# main node: ID-032-983
# main node: ID-033-245
# parent node: ID-096-214
# parent node: ID-097-378
# parent node: ID-098-535
# main node: ID-034-332
# main node: ID-035-201
# main node: ID-036-676
# main node: ID-038-716
# main node: ID-039-217
# main node: ID-040-243
# main node: ID-041-402
# main node: ID-042-189
# main node: ID-043-150
# main node: ID-044-498
# main node: ID-045-335
# main node: ID-046-240
# parent node: ID-049-855
# parent node: ID-050-720
# parent node: ID-051-563
# parent node: ID-052-345
# parent node: ID-053-731
# parent node: ID-054-887
# parent node: ID-055-848
# parent node: ID-056-519
# parent node: ID-057-425
# parent node: ID-058-363
# parent node: ID-059-251
# parent node: ID-060-849
# parent node: ID-061-296
# parent node: ID-064-653
# parent node: ID-065-906
# parent node: ID-066-826
# parent node: ID-067-967
# parent node: ID-068-774
# parent node: ID-073-450
# parent node: ID-074-451
# parent node: ID-075-266
# parent node: ID-076-997
# parent node: ID-077-281
# parent node: ID-078-914
# parent node: ID-079-466
# parent node: ID-080-677
# parent node: ID-081-480
# parent node: ID-082-718
# parent node: ID-086-474
# parent node: ID-087-286
# parent node: ID-088-916
# parent node: ID-089-723
# parent node: ID-090-485
# parent node: ID-091-105
# parent node: ID-093-937
# parent node: ID-094-369
# parent node: ID-095-734
# main node: ID-092-720
# parent node: ID-099-829
# parent node: ID-100-476
# parent node: ID-101-626
# parent node: ID-102-525

# %%
print(json.dumps(node_relationships.table, indent=4))
# Out:
# [
#     {
#         "id": "ID-002-528",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-003-270",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-004-742",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-005-497",
#         "parents": [
#             "ID-018-195",
#             "ID-019-410"
#         ],
#         "children": [
#             "ID-007-148",
#             "ID-008-662"
#         ]
#     },
#     {
#         "id": "ID-018-195",
#         "parents": [
#             "ID-017-925"
#         ],
#         "children": [
#             "ID-005-497",
#             "ID-020-312"
#         ]
#     },
#     {
#         "id": "ID-019-410",
#         "parents": [
#             "ID-017-925"
#         ],
#         "children": [
#             "ID-005-497",
#             "ID-020-312"
#         ]
#     },
#     {
#         "id": "ID-006-400",
#         "parents": [
#             "ID-013-399",
#             "ID-014-944",
#             "ID-015-251",
#             "ID-016-980"
#         ],
#         "children": [
#             "ID-007-148",
#             "ID-008-662"
#         ]
#     },
#     {
#         "id": "ID-013-399",
#         "parents": [
#             "ID-047-939",
#             "ID-048-126"
#         ],
#         "children": [
#             "ID-006-400",
#             "ID-017-925"
#         ]
#     },
#     {
#         "id": "ID-014-944",
#         "parents": [
#             "ID-062-375",
#             "ID-063-325"
#         ],
#         "children": [
#             "ID-006-400",
#             "ID-017-925"
#         ]
#     },
#     {
#         "id": "ID-015-251",
#         "parents": [
#             "ID-069-498",
#             "ID-070-555",
#             "ID-071-274",
#             "ID-072-840"
#         ],
#         "children": [
#             "ID-006-400",
#             "ID-016-980",
#             "ID-017-925",
#             "ID-021-108"
#         ]
#     },
#     {
#         "id": "ID-016-980",
#         "parents": [
#             "ID-015-251"
#         ],
#         "children": [
#             "ID-006-400",
#             "ID-017-925"
#         ]
#     },
#     {
#         "id": "ID-007-148",
#         "parents": [
#             "ID-005-497",
#             "ID-006-400"
#         ],
#         "children": [
#             "ID-008-662"
#         ]
#     },
#     {
#         "id": "ID-008-662",
#         "parents": [
#             "ID-005-497",
#             "ID-006-400",
#             "ID-007-148"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-009-878",
#         "parents": [
#             "ID-037-380"
#         ],
#         "children": [
#             "ID-011-599"
#         ]
#     },
#     {
#         "id": "ID-037-380",
#         "parents": [
#             "ID-032-983",
#             "ID-036-676"
#         ],
#         "children": [
#             "ID-009-878",
#             "ID-010-747"
#         ]
#     },
#     {
#         "id": "ID-010-747",
#         "parents": [
#             "ID-037-380"
#         ],
#         "children": [
#             "ID-011-599"
#         ]
#     },
#     {
#         "id": "ID-011-599",
#         "parents": [
#             "ID-009-878",
#             "ID-010-747"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-012-524",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-047-939",
#         "parents": [
#             "ID-049-855",
#             "ID-050-720",
#             "ID-051-563"
#         ],
#         "children": [
#             "ID-013-399",
#             "ID-048-126"
#         ]
#     },
#     {
#         "id": "ID-048-126",
#         "parents": [
#             "ID-047-939"
#         ],
#         "children": [
#             "ID-013-399"
#         ]
#     },
#     {
#         "id": "ID-062-375",
#         "parents": [
#             "ID-064-653",
#             "ID-065-906",
#             "ID-066-826",
#             "ID-067-967",
#             "ID-068-774"
#         ],
#         "children": [
#             "ID-014-944",
#             "ID-063-325"
#         ]
#     },
#     {
#         "id": "ID-063-325",
#         "parents": [
#             "ID-062-375"
#         ],
#         "children": [
#             "ID-014-944"
#         ]
#     },
#     {
#         "id": "ID-069-498",
#         "parents": [
#             "ID-073-450",
#             "ID-074-451",
#             "ID-075-266",
#             "ID-076-997",
#             "ID-077-281",
#             "ID-078-914"
#         ],
#         "children": [
#             "ID-015-251",
#             "ID-070-555",
#             "ID-099-829"
#         ]
#     },
#     {
#         "id": "ID-070-555",
#         "parents": [
#             "ID-069-498",
#             "ID-079-466",
#             "ID-080-677",
#             "ID-081-480",
#             "ID-082-718"
#         ],
#         "children": [
#             "ID-015-251",
#             "ID-071-274"
#         ]
#     },
#     {
#         "id": "ID-071-274",
#         "parents": [
#             "ID-070-555"
#         ],
#         "children": [
#             "ID-015-251",
#             "ID-072-840"
#         ]
#     },
#     {
#         "id": "ID-072-840",
#         "parents": [
#             "ID-071-274"
#         ],
#         "children": [
#             "ID-015-251"
#         ]
#     },
#     {
#         "id": "ID-017-925",
#         "parents": [
#             "ID-013-399",
#             "ID-014-944",
#             "ID-015-251",
#             "ID-016-980"
#         ],
#         "children": [
#             "ID-018-195",
#             "ID-019-410",
#             "ID-024-388",
#             "ID-039-217",
#             "ID-040-243",
#             "ID-042-189"
#         ]
#     },
#     {
#         "id": "ID-020-312",
#         "parents": [
#             "ID-018-195",
#             "ID-019-410"
#         ],
#         "children": [
#             "ID-024-388",
#             "ID-039-217",
#             "ID-040-243",
#             "ID-042-189"
#         ]
#     },
#     {
#         "id": "ID-021-108",
#         "parents": [
#             "ID-015-251"
#         ],
#         "children": [
#             "ID-022-200",
#             "ID-023-455"
#         ]
#     },
#     {
#         "id": "ID-022-200",
#         "parents": [
#             "ID-021-108"
#         ],
#         "children": [
#             "ID-023-455"
#         ]
#     },
#     {
#         "id": "ID-023-455",
#         "parents": [
#             "ID-021-108",
#             "ID-022-200"
#         ],
#         "children": [
#             "ID-024-388",
#             "ID-039-217",
#             "ID-040-243",
#             "ID-042-189"
#         ]
#     },
#     {
#         "id": "ID-024-388",
#         "parents": [
#             "ID-017-925",
#             "ID-020-312",
#             "ID-023-455"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-025-803",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-026-947",
#         "parents": [],
#         "children": [
#             "ID-027-918"
#         ]
#     },
#     {
#         "id": "ID-027-918",
#         "parents": [
#             "ID-026-947"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-028-310",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-029-120",
#         "parents": [
#             "ID-083-154",
#             "ID-084-311",
#             "ID-085-702"
#         ],
#         "children": [
#             "ID-030-975"
#         ]
#     },
#     {
#         "id": "ID-083-154",
#         "parents": [
#             "ID-086-474",
#             "ID-087-286"
#         ],
#         "children": [
#             "ID-029-120",
#             "ID-085-702"
#         ]
#     },
#     {
#         "id": "ID-084-311",
#         "parents": [
#             "ID-088-916",
#             "ID-089-723"
#         ],
#         "children": [
#             "ID-029-120",
#             "ID-085-702"
#         ]
#     },
#     {
#         "id": "ID-085-702",
#         "parents": [
#             "ID-083-154",
#             "ID-084-311"
#         ],
#         "children": [
#             "ID-029-120"
#         ]
#     },
#     {
#         "id": "ID-030-975",
#         "parents": [
#             "ID-029-120"
#         ],
#         "children": [
#             "ID-031-676",
#             "ID-039-217",
#             "ID-040-243",
#             "ID-042-189"
#         ]
#     },
#     {
#         "id": "ID-031-676",
#         "parents": [
#             "ID-030-975"
#         ],
#         "children": [
#             "ID-032-983"
#         ]
#     },
#     {
#         "id": "ID-032-983",
#         "parents": [
#             "ID-031-676"
#         ],
#         "children": [
#             "ID-037-380",
#             "ID-039-217",
#             "ID-040-243",
#             "ID-042-189"
#         ]
#     },
#     {
#         "id": "ID-033-245",
#         "parents": [
#             "ID-096-214",
#             "ID-097-378",
#             "ID-098-535"
#         ],
#         "children": [
#             "ID-034-332",
#             "ID-035-201"
#         ]
#     },
#     {
#         "id": "ID-096-214",
#         "parents": [
#             "ID-099-829",
#             "ID-100-476",
#             "ID-101-626",
#             "ID-102-525"
#         ],
#         "children": [
#             "ID-033-245",
#             "ID-097-378"
#         ]
#     },
#     {
#         "id": "ID-097-378",
#         "parents": [
#             "ID-096-214"
#         ],
#         "children": [
#             "ID-033-245",
#             "ID-098-535"
#         ]
#     },
#     {
#         "id": "ID-098-535",
#         "parents": [
#             "ID-097-378"
#         ],
#         "children": [
#             "ID-033-245"
#         ]
#     },
#     {
#         "id": "ID-034-332",
#         "parents": [
#             "ID-033-245"
#         ],
#         "children": [
#             "ID-039-217",
#             "ID-040-243",
#             "ID-042-189"
#         ]
#     },
#     {
#         "id": "ID-035-201",
#         "parents": [
#             "ID-033-245"
#         ],
#         "children": [
#             "ID-036-676"
#         ]
#     },
#     {
#         "id": "ID-036-676",
#         "parents": [
#             "ID-035-201"
#         ],
#         "children": [
#             "ID-037-380",
#             "ID-039-217",
#             "ID-040-243",
#             "ID-042-189"
#         ]
#     },
#     {
#         "id": "ID-038-716",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-039-217",
#         "parents": [
#             "ID-017-925",
#             "ID-020-312",
#             "ID-023-455",
#             "ID-030-975",
#             "ID-032-983",
#             "ID-034-332",
#             "ID-036-676"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-040-243",
#         "parents": [
#             "ID-017-925",
#             "ID-020-312",
#             "ID-023-455",
#             "ID-030-975",
#             "ID-032-983",
#             "ID-034-332",
#             "ID-036-676"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-041-402",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-042-189",
#         "parents": [
#             "ID-017-925",
#             "ID-020-312",
#             "ID-023-455",
#             "ID-030-975",
#             "ID-032-983",
#             "ID-034-332",
#             "ID-036-676"
#         ],
#         "children": [
#             "ID-043-150"
#         ]
#     },
#     {
#         "id": "ID-043-150",
#         "parents": [
#             "ID-042-189"
#         ],
#         "children": [
#             "ID-045-335",
#             "ID-046-240"
#         ]
#     },
#     {
#         "id": "ID-044-498",
#         "parents": [],
#         "children": []
#     },
#     {
#         "id": "ID-045-335",
#         "parents": [
#             "ID-043-150"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-046-240",
#         "parents": [
#             "ID-043-150"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-049-855",
#         "parents": [
#             "ID-052-345",
#             "ID-053-731"
#         ],
#         "children": [
#             "ID-047-939",
#             "ID-050-720",
#             "ID-065-906",
#             "ID-090-485"
#         ]
#     },
#     {
#         "id": "ID-050-720",
#         "parents": [
#             "ID-049-855"
#         ],
#         "children": [
#             "ID-047-939",
#             "ID-051-563"
#         ]
#     },
#     {
#         "id": "ID-051-563",
#         "parents": [
#             "ID-050-720"
#         ],
#         "children": [
#             "ID-047-939"
#         ]
#     },
#     {
#         "id": "ID-052-345",
#         "parents": [
#             "ID-054-887",
#             "ID-055-848",
#             "ID-056-519",
#             "ID-057-425"
#         ],
#         "children": [
#             "ID-049-855",
#             "ID-053-731"
#         ]
#     },
#     {
#         "id": "ID-053-731",
#         "parents": [
#             "ID-052-345"
#         ],
#         "children": [
#             "ID-049-855"
#         ]
#     },
#     {
#         "id": "ID-054-887",
#         "parents": [],
#         "children": [
#             "ID-052-345",
#             "ID-055-848",
#             "ID-057-425",
#             "ID-091-105"
#         ]
#     },
#     {
#         "id": "ID-055-848",
#         "parents": [
#             "ID-054-887",
#             "ID-058-363",
#             "ID-059-251",
#             "ID-060-849",
#             "ID-061-296"
#         ],
#         "children": [
#             "ID-052-345",
#             "ID-056-519"
#         ]
#     },
#     {
#         "id": "ID-056-519",
#         "parents": [
#             "ID-055-848"
#         ],
#         "children": [
#             "ID-052-345",
#             "ID-057-425"
#         ]
#     },
#     {
#         "id": "ID-057-425",
#         "parents": [
#             "ID-054-887",
#             "ID-056-519"
#         ],
#         "children": [
#             "ID-052-345"
#         ]
#     },
#     {
#         "id": "ID-058-363",
#         "parents": [],
#         "children": [
#             "ID-055-848",
#             "ID-059-251",
#             "ID-073-450"
#         ]
#     },
#     {
#         "id": "ID-059-251",
#         "parents": [
#             "ID-058-363"
#         ],
#         "children": [
#             "ID-055-848",
#             "ID-060-849",
#             "ID-061-296"
#         ]
#     },
#     {
#         "id": "ID-060-849",
#         "parents": [
#             "ID-059-251"
#         ],
#         "children": [
#             "ID-055-848",
#             "ID-061-296"
#         ]
#     },
#     {
#         "id": "ID-061-296",
#         "parents": [
#             "ID-059-251",
#             "ID-060-849"
#         ],
#         "children": [
#             "ID-055-848"
#         ]
#     },
#     {
#         "id": "ID-064-653",
#         "parents": [],
#         "children": [
#             "ID-062-375",
#             "ID-066-826",
#             "ID-090-485",
#             "ID-091-105"
#         ]
#     },
#     {
#         "id": "ID-065-906",
#         "parents": [
#             "ID-049-855"
#         ],
#         "children": [
#             "ID-062-375",
#             "ID-066-826"
#         ]
#     },
#     {
#         "id": "ID-066-826",
#         "parents": [
#             "ID-064-653",
#             "ID-065-906"
#         ],
#         "children": [
#             "ID-062-375",
#             "ID-067-967"
#         ]
#     },
#     {
#         "id": "ID-067-967",
#         "parents": [
#             "ID-066-826"
#         ],
#         "children": [
#             "ID-062-375",
#             "ID-068-774"
#         ]
#     },
#     {
#         "id": "ID-068-774",
#         "parents": [
#             "ID-067-967"
#         ],
#         "children": [
#             "ID-062-375"
#         ]
#     },
#     {
#         "id": "ID-073-450",
#         "parents": [
#             "ID-058-363"
#         ],
#         "children": [
#             "ID-069-498",
#             "ID-074-451"
#         ]
#     },
#     {
#         "id": "ID-074-451",
#         "parents": [
#             "ID-073-450"
#         ],
#         "children": [
#             "ID-069-498",
#             "ID-077-281"
#         ]
#     },
#     {
#         "id": "ID-075-266",
#         "parents": [],
#         "children": [
#             "ID-069-498",
#             "ID-076-997"
#         ]
#     },
#     {
#         "id": "ID-076-997",
#         "parents": [
#             "ID-075-266"
#         ],
#         "children": [
#             "ID-069-498",
#             "ID-100-476"
#         ]
#     },
#     {
#         "id": "ID-077-281",
#         "parents": [
#             "ID-074-451"
#         ],
#         "children": [
#             "ID-069-498",
#             "ID-078-914"
#         ]
#     },
#     {
#         "id": "ID-078-914",
#         "parents": [
#             "ID-077-281"
#         ],
#         "children": [
#             "ID-069-498"
#         ]
#     },
#     {
#         "id": "ID-079-466",
#         "parents": [],
#         "children": [
#             "ID-070-555",
#             "ID-080-677"
#         ]
#     },
#     {
#         "id": "ID-080-677",
#         "parents": [
#             "ID-079-466"
#         ],
#         "children": [
#             "ID-070-555",
#             "ID-081-480",
#             "ID-101-626"
#         ]
#     },
#     {
#         "id": "ID-081-480",
#         "parents": [
#             "ID-080-677"
#         ],
#         "children": [
#             "ID-070-555",
#             "ID-082-718"
#         ]
#     },
#     {
#         "id": "ID-082-718",
#         "parents": [
#             "ID-081-480"
#         ],
#         "children": [
#             "ID-070-555"
#         ]
#     },
#     {
#         "id": "ID-086-474",
#         "parents": [
#             "ID-090-485",
#             "ID-091-105"
#         ],
#         "children": [
#             "ID-083-154",
#             "ID-087-286"
#         ]
#     },
#     {
#         "id": "ID-087-286",
#         "parents": [
#             "ID-086-474"
#         ],
#         "children": [
#             "ID-083-154"
#         ]
#     },
#     {
#         "id": "ID-088-916",
#         "parents": [
#             "ID-093-937",
#             "ID-094-369",
#             "ID-095-734"
#         ],
#         "children": [
#             "ID-084-311",
#             "ID-089-723"
#         ]
#     },
#     {
#         "id": "ID-089-723",
#         "parents": [
#             "ID-088-916"
#         ],
#         "children": [
#             "ID-084-311"
#         ]
#     },
#     {
#         "id": "ID-090-485",
#         "parents": [
#             "ID-049-855",
#             "ID-064-653"
#         ],
#         "children": [
#             "ID-086-474",
#             "ID-092-720"
#         ]
#     },
#     {
#         "id": "ID-091-105",
#         "parents": [
#             "ID-054-887",
#             "ID-064-653"
#         ],
#         "children": [
#             "ID-086-474",
#             "ID-092-720"
#         ]
#     },
#     {
#         "id": "ID-093-937",
#         "parents": [],
#         "children": [
#             "ID-088-916",
#             "ID-094-369",
#             "ID-095-734"
#         ]
#     },
#     {
#         "id": "ID-094-369",
#         "parents": [
#             "ID-093-937"
#         ],
#         "children": [
#             "ID-088-916",
#             "ID-095-734"
#         ]
#     },
#     {
#         "id": "ID-095-734",
#         "parents": [
#             "ID-093-937",
#             "ID-094-369"
#         ],
#         "children": [
#             "ID-088-916"
#         ]
#     },
#     {
#         "id": "ID-092-720",
#         "parents": [
#             "ID-090-485",
#             "ID-091-105"
#         ],
#         "children": []
#     },
#     {
#         "id": "ID-099-829",
#         "parents": [
#             "ID-069-498"
#         ],
#         "children": [
#             "ID-096-214",
#             "ID-102-525"
#         ]
#     },
#     {
#         "id": "ID-100-476",
#         "parents": [
#             "ID-076-997"
#         ],
#         "children": [
#             "ID-096-214",
#             "ID-102-525"
#         ]
#     },
#     {
#         "id": "ID-101-626",
#         "parents": [
#             "ID-080-677"
#         ],
#         "children": [
#             "ID-096-214",
#             "ID-102-525"
#         ]
#     },
#     {
#         "id": "ID-102-525",
#         "parents": [
#             "ID-099-829",
#             "ID-100-476",
#             "ID-101-626"
#         ],
#         "children": [
#             "ID-096-214"
#         ]
#     }
# ]

# %%
# Step 3

# %%
node_orders = NodeOrders()

# %%
# Initiate the color table with all nodes uncolored

for row in node_relationships.table:
    node_orders.initiate_new_node(row['id'])

# %%
# Iteration 1

# Go through all the nodes. The nodes having no dependency/component will be assigned order = 1 
# (the order (color) data of these nodes will be saved to a dictionary name node_order)

current_order = 1

for row in node_relationships.table:
    if row["parents"] == []:
        node_orders.assign_order(row['id'], current_order)

# %%
node_orders.get_ordered_nodes()
# Out:
# ['ID-002-528',
#  'ID-003-270',
#  'ID-004-742',
#  'ID-012-524',
#  'ID-025-803',
#  'ID-026-947',
#  'ID-028-310',
#  'ID-038-716',
#  'ID-041-402',
#  'ID-044-498',
#  'ID-054-887',
#  'ID-058-363',
#  'ID-064-653',
#  'ID-075-266',
#  'ID-079-466',
#  'ID-093-937']

# %%
# Iteration N (N>=2):

# Current order = N
# Go through all the nodes that have been colored (order-assigned), 
# check the un-ordered (un-colored) children of these nodes.
# If all the parent nodes of that child node have been order-assigned an order 
# which is less than N (can be N-1, N-2, anything but cannot be N) --> update the order of the child node to N
# Else, that child node will not be colored in this round 
# (because some of the work items that it depends on have not been completed so it cannot start this round)

current_order = 1

while node_orders.get_unordered_nodes() != []:
    
    current_order += 1
    
    colored_nodes = node_orders.get_ordered_nodes()
    
    for node in colored_nodes:
        
        current_node_children = node_relationships.get_children(node)
        
        for child_node in current_node_children:
            
            child_node_order = node_orders.get_node_order(child_node)
            
            if child_node_order == -1:
                
                parent_nodes_of_the_child = node_relationships.get_parents(child_node)
                
                to_color = True
                
                for parent_node in parent_nodes_of_the_child:
                    
                    parent_node_order = node_orders.get_node_order(parent_node)
                    
                    if parent_node_order == -1 or parent_node_order == current_order:
                        
                        to_color = False
                        
                if to_color:
                    
                    node_orders.assign_order(child_node, current_order)

# %%
node_orders.table
# Out:
# [{'id': 'ID-002-528', 'order': 1},
#  {'id': 'ID-003-270', 'order': 1},
#  {'id': 'ID-004-742', 'order': 1},
#  {'id': 'ID-005-497', 'order': 20},
#  {'id': 'ID-018-195', 'order': 19},
#  {'id': 'ID-019-410', 'order': 19},
#  {'id': 'ID-006-400', 'order': 18},
#  {'id': 'ID-013-399', 'order': 15},
#  {'id': 'ID-014-944', 'order': 17},
#  {'id': 'ID-015-251', 'order': 10},
#  {'id': 'ID-016-980', 'order': 11},
#  {'id': 'ID-007-148', 'order': 21},
#  {'id': 'ID-008-662', 'order': 22},
#  {'id': 'ID-009-878', 'order': 21},
#  {'id': 'ID-037-380', 'order': 20},
#  {'id': 'ID-010-747', 'order': 21},
#  {'id': 'ID-011-599', 'order': 22},
#  {'id': 'ID-012-524', 'order': 1},
#  {'id': 'ID-047-939', 'order': 13},
#  {'id': 'ID-048-126', 'order': 14},
#  {'id': 'ID-062-375', 'order': 15},
#  {'id': 'ID-063-325', 'order': 16},
#  {'id': 'ID-069-498', 'order': 6},
#  {'id': 'ID-070-555', 'order': 7},
#  {'id': 'ID-071-274', 'order': 8},
#  {'id': 'ID-072-840', 'order': 9},
#  {'id': 'ID-017-925', 'order': 18},
#  {'id': 'ID-020-312', 'order': 20},
#  {'id': 'ID-021-108', 'order': 11},
#  {'id': 'ID-022-200', 'order': 12},
#  {'id': 'ID-023-455', 'order': 13},
#  {'id': 'ID-024-388', 'order': 21},
#  {'id': 'ID-025-803', 'order': 1},
#  {'id': 'ID-026-947', 'order': 1},
#  {'id': 'ID-027-918', 'order': 2},
#  {'id': 'ID-028-310', 'order': 1},
#  {'id': 'ID-029-120', 'order': 16},
#  {'id': 'ID-083-154', 'order': 14},
#  {'id': 'ID-084-311', 'order': 6},
#  {'id': 'ID-085-702', 'order': 15},
#  {'id': 'ID-030-975', 'order': 17},
#  {'id': 'ID-031-676', 'order': 18},
#  {'id': 'ID-032-983', 'order': 19},
#  {'id': 'ID-033-245', 'order': 12},
#  {'id': 'ID-096-214', 'order': 9},
#  {'id': 'ID-097-378', 'order': 10},
#  {'id': 'ID-098-535', 'order': 11},
#  {'id': 'ID-034-332', 'order': 13},
#  {'id': 'ID-035-201', 'order': 13},
#  {'id': 'ID-036-676', 'order': 14},
#  {'id': 'ID-038-716', 'order': 1},
#  {'id': 'ID-039-217', 'order': 21},
#  {'id': 'ID-040-243', 'order': 21},
#  {'id': 'ID-041-402', 'order': 1},
#  {'id': 'ID-042-189', 'order': 21},
#  {'id': 'ID-043-150', 'order': 22},
#  {'id': 'ID-044-498', 'order': 1},
#  {'id': 'ID-045-335', 'order': 23},
#  {'id': 'ID-046-240', 'order': 23},
#  {'id': 'ID-049-855', 'order': 10},
#  {'id': 'ID-050-720', 'order': 11},
#  {'id': 'ID-051-563', 'order': 12},
#  {'id': 'ID-052-345', 'order': 8},
#  {'id': 'ID-053-731', 'order': 9},
#  {'id': 'ID-054-887', 'order': 1},
#  {'id': 'ID-055-848', 'order': 5},
#  {'id': 'ID-056-519', 'order': 6},
#  {'id': 'ID-057-425', 'order': 7},
#  {'id': 'ID-058-363', 'order': 1},
#  {'id': 'ID-059-251', 'order': 2},
#  {'id': 'ID-060-849', 'order': 3},
#  {'id': 'ID-061-296', 'order': 4},
#  {'id': 'ID-064-653', 'order': 1},
#  {'id': 'ID-065-906', 'order': 11},
#  {'id': 'ID-066-826', 'order': 12},
#  {'id': 'ID-067-967', 'order': 13},
#  {'id': 'ID-068-774', 'order': 14},
#  {'id': 'ID-073-450', 'order': 2},
#  {'id': 'ID-074-451', 'order': 3},
#  {'id': 'ID-075-266', 'order': 1},
#  {'id': 'ID-076-997', 'order': 2},
#  {'id': 'ID-077-281', 'order': 4},
#  {'id': 'ID-078-914', 'order': 5},
#  {'id': 'ID-079-466', 'order': 1},
#  {'id': 'ID-080-677', 'order': 2},
#  {'id': 'ID-081-480', 'order': 3},
#  {'id': 'ID-082-718', 'order': 4},
#  {'id': 'ID-086-474', 'order': 12},
#  {'id': 'ID-087-286', 'order': 13},
#  {'id': 'ID-088-916', 'order': 4},
#  {'id': 'ID-089-723', 'order': 5},
#  {'id': 'ID-090-485', 'order': 11},
#  {'id': 'ID-091-105', 'order': 2},
#  {'id': 'ID-093-937', 'order': 1},
#  {'id': 'ID-094-369', 'order': 2},
#  {'id': 'ID-095-734', 'order': 3},
#  {'id': 'ID-092-720', 'order': 12},
#  {'id': 'ID-099-829', 'order': 7},
#  {'id': 'ID-100-476', 'order': 3},
#  {'id': 'ID-101-626', 'order': 3},
#  {'id': 'ID-102-525', 'order': 8}]

# %%
node_orders.get_nodes_of_order(7)
# Out:
# ['ID-070-555', 'ID-057-425', 'ID-099-829']

# %%
node_orders.get_highest_order()
# Out:
# 23

# %%
for i in range(1,24):
    print("Order {}:".format(i))
    print(node_orders.get_nodes_of_order(i))
    print()
# Out:
# Order 1:
# ['ID-002-528', 'ID-003-270', 'ID-004-742', 'ID-012-524', 'ID-025-803', 'ID-026-947', 'ID-028-310', 'ID-038-716', 'ID-041-402', 'ID-044-498', 'ID-054-887', 'ID-058-363', 'ID-064-653', 'ID-075-266', 'ID-079-466', 'ID-093-937']
#
# Order 2:
# ['ID-027-918', 'ID-059-251', 'ID-073-450', 'ID-076-997', 'ID-080-677', 'ID-091-105', 'ID-094-369']
#
# Order 3:
# ['ID-060-849', 'ID-074-451', 'ID-081-480', 'ID-095-734', 'ID-100-476', 'ID-101-626']
#
# Order 4:
# ['ID-061-296', 'ID-077-281', 'ID-082-718', 'ID-088-916']
#
# Order 5:
# ['ID-055-848', 'ID-078-914', 'ID-089-723']
#
# Order 6:
# ['ID-069-498', 'ID-084-311', 'ID-056-519']
#
# Order 7:
# ['ID-070-555', 'ID-057-425', 'ID-099-829']
#
# Order 8:
# ['ID-071-274', 'ID-052-345', 'ID-102-525']
#
# Order 9:
# ['ID-072-840', 'ID-096-214', 'ID-053-731']
#
# Order 10:
# ['ID-015-251', 'ID-097-378', 'ID-049-855']
#
# Order 11:
# ['ID-016-980', 'ID-021-108', 'ID-098-535', 'ID-050-720', 'ID-065-906', 'ID-090-485']
#
# Order 12:
# ['ID-022-200', 'ID-033-245', 'ID-051-563', 'ID-066-826', 'ID-086-474', 'ID-092-720']
#
# Order 13:
# ['ID-047-939', 'ID-023-455', 'ID-034-332', 'ID-035-201', 'ID-067-967', 'ID-087-286']
#
# Order 14:
# ['ID-048-126', 'ID-083-154', 'ID-036-676', 'ID-068-774']
#
# Order 15:
# ['ID-013-399', 'ID-062-375', 'ID-085-702']
#
# Order 16:
# ['ID-063-325', 'ID-029-120']
#
# Order 17:
# ['ID-014-944', 'ID-030-975']
#
# Order 18:
# ['ID-006-400', 'ID-017-925', 'ID-031-676']
#
# Order 19:
# ['ID-018-195', 'ID-019-410', 'ID-032-983']
#
# Order 20:
# ['ID-005-497', 'ID-037-380', 'ID-020-312']
#
# Order 21:
# ['ID-007-148', 'ID-009-878', 'ID-010-747', 'ID-024-388', 'ID-039-217', 'ID-040-243', 'ID-042-189']
#
# Order 22:
# ['ID-008-662', 'ID-011-599', 'ID-043-150']
#
# Order 23:
# ['ID-045-335', 'ID-046-240']

# %%
df_work_and_order = pd.DataFrame(node_orders.table)

# %%
df_work_and_order
# Out:
#              id  order
# 0    ID-002-528      1
# 1    ID-003-270      1
# 2    ID-004-742      1
# 3    ID-005-497     20
# 4    ID-018-195     19
# ..          ...    ...
# 96   ID-092-720     12
# 97   ID-099-829      7
# 98   ID-100-476      3
# 99   ID-101-626      3
# 100  ID-102-525      8
#
# [101 rows x 2 columns]

# %%
df_work_and_order.to_csv("output/work_order.csv")
